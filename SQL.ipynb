# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'nama' : ['irfan', 'sardi', 'irwan', 'tono', 'irwan', 'irwan', 'irwan'],
    'umur' : [20,24, 23, 25, 23, 23, 23],
    'alamat' : ['jakarta', 'bekasi', 'bekasi', 'bekasi', 'bekasi', 'bekasi', 'bekasi']
})

# %%
df.tail()
# Out:
#    Order_ID           Date_Time Customer_ID     Product  Quantity  Price  \
# 0       101 2023-07-15 10:30:00        C001      Laptop         1   1000
# 1       102 2023-07-16 15:45:00        C002    Keyboard         2    250
# 2       103 2023-07-17 12:00:00        C003     Monitor         3    350
# 3       104 2023-07-18 09:00:00        C004       Mouse         4     75
# 4       105 2023-07-19 16:20:00        C005  Headphones         5    120
#
#    Year  Month  Day
# 0  2023      7   15
# 1  2023      7   16
# 2  2023      7   17
# 3  2023      7   18
# 4  2023      7   19

# %%
df.sample(3)
# Out:
#     nama  umur   alamat
# 0  irfan    20  jakarta
# 1  sardi    24   bekasi
# 2  irwan    23   bekasi

# %%
df.to_csv('nama_student.csv')

# %%
df.to_csv('nama_student.csv', index=False)

# %%
df_1 = pd.read_csv('nama_student.csv')
df_1
# Out:
#    Unnamed: 0   nama  umur   alamat
# 0           0  irfan    20  jakarta
# 1           1  sardi    24   bekasi
# 2           2  irwan    23   bekasi
# 3           3   tono    25   bekasi
# 4           4  irwan    23   bekasi
# 5           5  irwan    23   bekasi
# 6           6  irwan    23   bekasi

# %%
df_2 = pd.read_csv('nama_student2.csv', sep="|")
df_2
# Out:
#     nama  umur   alamat
# 0  irfan    20  jakarta
# 1  sardi    24   bekasi
# 2  irwan    23   bekasi
# 3   tono    25   bekasi
# 4  irwan    23   bekasi
# 5  irwan    23   bekasi
# 6  irwan    23   bekasi

# %%
data_2 = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv')
data_2.head()
# Out:
#                    division         conference  school_name  \
# 0  FBS (Division I-A Teams)  American Athletic   Cincinnati
# 1  FBS (Division I-A Teams)  American Athletic  Connecticut
# 2  FBS (Division I-A Teams)  American Athletic      Houston
# 3  FBS (Division I-A Teams)  American Athletic   Louisville
# 4  FBS (Division I-A Teams)  American Athletic      Memphis
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1
# 1    http://espn.go.com/ncf/teams/roster?teamId=41   2
# 2   http://espn.go.com/ncf/teams/roster?teamId=248   3
# 3    http://espn.go.com/ncf/teams/roster?teamId=97   4
# 4   http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   division     252 non-null    object
#  1   conference   252 non-null    object
#  2   school_name  252 non-null    object
#  3   roster_url   252 non-null    object
#  4   id           252 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 10.0+ KB

# %%
data_2.shape
# Out:
# (252, 5)

# %%
data_2.shape[1]
# Out:
# 5

# %%
data_2.query('conference=="American Athletic"')
# Out:
#                    division         conference         school_name  \
# 0  FBS (Division I-A Teams)  American Athletic          Cincinnati
# 1  FBS (Division I-A Teams)  American Athletic         Connecticut
# 2  FBS (Division I-A Teams)  American Athletic             Houston
# 3  FBS (Division I-A Teams)  American Athletic          Louisville
# 4  FBS (Division I-A Teams)  American Athletic             Memphis
# 5  FBS (Division I-A Teams)  American Athletic             Rutgers
# 6  FBS (Division I-A Teams)  American Athletic       South Florida
# 7  FBS (Division I-A Teams)  American Athletic  Southern Methodist
# 8  FBS (Division I-A Teams)  American Athletic              Temple
# 9  FBS (Division I-A Teams)  American Athletic                 UCF
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1
# 1    http://espn.go.com/ncf/teams/roster?teamId=41   2
# 2   http://espn.go.com/ncf/teams/roster?teamId=248   3
# ...

# %%
data_2[data_2['school_name']=='Cincinnati']
# Out:
#                    division         conference school_name  \
# 0  FBS (Division I-A Teams)  American Athletic  Cincinnati
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1

# %%
data_2.describe(include='object')
# Out:
#                         division      conference school_name  \
# count                        252             252         252
# unique                         2              25         252
# top     FBS (Division I-A Teams)  Conference USA  Cincinnati
# freq                         126              14           1
#
#                                              roster_url
# count                                               252
# unique                                              252
# top     http://espn.go.com/ncf/teams/roster?teamId=2132
# freq                                                  1

# %%
data_2['division'].value_counts()
# Out:
# division
# FBS (Division I-A Teams)     126
# FCS (Division I-AA Teams)    126
# Name: count, dtype: int64

# %%
data_2['conference'].nunique()
# Out:
# 25

# %%
len(data_2['conference']).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 len(data_2['conference']).unique()
#
# AttributeError: 'int' object has no attribute 'unique'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/cities_world.tsv', delimiter='\t')

# %%
df.sort_values(by='Population',ascending=False) [['City', 'Population']].head() #ascending
# Out:
#              City  Population
# 0  Tokyo/Yokohama    33200000
# 1  New York Metro    17800000
# 2       Sao Paulo    17700000
# 3   Seoul/Incheon    17500000
# 4     Mexico City    17400000

# %%
df[['City', 'Population']]
# Out:
#                          City  Population
# 0              Tokyo/Yokohama    33200000
# 1              New York Metro    17800000
# 2                   Sao Paulo    17700000
# 3               Seoul/Incheon    17500000
# 4                 Mexico City    17400000
# ..                        ...         ...
# 120                Copenhagen     1525000
# 121                  Brisbane     1508000
# 122  Riverside/San Bernardino     1507000
# 123                Cincinnati     1503000
# 124                     Accra     1500000
#
# [125 rows x 2 columns]

# %%
df.iloc[]

# %%
house = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/kc_house_data.csv')
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.loc[0:3,:]
# Out:
#              City  Latitude  Longitude      Country  Population  Land_area  \
# 0  Tokyo/Yokohama   35.6895   139.6917        Japan    33200000       6993
# 1  New York Metro   40.7128   -74.0059          USA    17800000       8683
# 2       Sao Paulo  -23.5505   -46.6333       Brazil    17700000       1968
# 3   Seoul/Incheon   37.5665   126.9780  South Korea    17500000       1049
#
#    Density  Number
# 0     4750       1
# 1     2050       2
# 2     9000       3
# 3    16700       4

# %%
df.iloc[0:4,0:4]
# Out:
#              City  Latitude  Longitude      Country
# 0  Tokyo/Yokohama   35.6895   139.6917        Japan
# 1  New York Metro   40.7128   -74.0059          USA
# 2       Sao Paulo  -23.5505   -46.6333       Brazil
# 3   Seoul/Incheon   37.5665   126.9780  South Korea

# %%
df.query("Population >10000000 & Latitude < 0")
# Out:
#               City  Latitude  Longitude    Country  Population  Land_area  \
# 2        Sao Paulo  -23.5505   -46.6333     Brazil    17700000       1968
# 9          Jakarta   -6.1745   106.8227  Indonesia    14250000       1360
# 14    Buenos Aires  -34.6037   -58.3816  Argentina    11200000       2266
# 15  Rio de Janeiro  -22.9068   -43.1729     Brazil    10800000       1580
#
#     Density  Number
# 2      9000       3
# 9     10500      10
# 14     4950      15
# 15     6850      16

# %%
list_country = [['Argentina', "Brazil', 'Chile']]

# %%
data = {
    'City': 'Surabaya',
    'Latitude': -7.2575,
    'Longitude': 112.7521,
    'Country': 'Indonesia',
    'Population': 2949585,
    'Land_area': 351,
    'Density': 8406,
    'Number':126
}
df = df.append(data,ignore_index=True)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v6/tfg0h80n4dq87291tslqlg0r0000gn/T/ipykernel_1953/2001000690.py in ?()
#       7     'Land_area': 351,
#       8     'Density': 8406,
#       9     'Number':126
#      10 }
# ---> 11 df = df.append(data,ignore_index=True)
#      12 df.tail()
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df_new2 = df.drop('City', axis=1, inplace =True),

# %%
df.groupby('Country').mean()
# Out:
#                Latitude   Longitude    Population    Land_area       Density  \
# Country
# Argentina    -34.603700  -58.381600  1.120000e+07  2266.000000   4950.000000
# Australia    -33.050733  149.732500  2.724000e+06  1790.000000   1516.666667
# Austria       48.208200   16.373800  1.550000e+06   453.000000   3400.000000
# Azerbaijan    40.409300   49.867100  2.100000e+06   544.000000   3850.000000
# Belgium       50.850300    4.351700  1.570000e+06   712.000000   2200.000000
# Brazil       -19.147167  -44.730333  5.205556e+06   853.444444   5338.888889
# Canada        46.145867  -92.023733  3.137667e+06  1505.000000   2050.000000
# Chile        -33.448900  -70.669300  5.425000e+06   648.000000   8400.000000
# China         35.580267  119.031033  6.385667e+06   542.500000  11483.333333
# Colombia       4.711000  -74.072100  7.000000e+06   518.000000  13500.000000
# Congo         -4.387100   15.970000  5.000000e+06   469.000000  10650.000000
# ...

# %%
df.drop('City', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df.drop('City', axis=1, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %% [markdown]
# ## afternoon class

# %%
import pandas as pd
import numpy as np

# %%
data = {'A': [1, 2, np.nan, 4, 5],
        'B': [10, 20, 30, np.nan, 50]}
df = pd.DataFrame(data)

df
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  NaN  30.0
# 3  4.0   NaN
# 4  5.0  50.0

# %%
print(df.mean())
# Out:
# A     3.0
# B    27.5
# dtype: float64

# %%
data = {'Name': ['Alice', 'Bob', None, 'Eve'],
        'Age': [25, None, 30, 35]}
df = pd.DataFrame(data)

df
# Out:
#     Name   Age
# 0  Alice  25.0
# 1    Bob   NaN
# 2   None  30.0
# 3    Eve  35.0

# %%
data = pd.DataFrame({'Column1': [1, 2, 'N/A', 4, 5],
        'Column2': [10, 'NA', 30, 40, 50]})
data
# Out:
#   Column1 Column2
# 0       1      10
# 1       2      NA
# 2     N/A      30
# 3       4      40
# 4       5      50

# %%
data.to_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.to_csv('data.csv')
#
# NameError: name 'data' is not defined

# %%
df = pd.read_csv('data.csv', na_values=['N/A', 'NA'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv('data.csv', na_values=['N/A', 'NA'])
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.head(2)
# Out:
#    Unnamed: 0  Column1  Column2
# 0           0      1.0     10.0
# 1           1      2.0      NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Column1       1
# Column2       1
# dtype: int64

# %%
df_filled = df.filledna({Quantity": 10, df['Quantity']})

# %%
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 import seaborn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import sys

print(sys.version)
print(sys.executable)
# Out:
# 3.12.3 (v3.12.3:f6650f9ad7, Apr  9 2024, 08:18:48) [Clang 13.0.0 (clang-1300.0.29.30)]
# /usr/local/bin/python3

# %%
df.iloc[2:3] = 3

# %%
for i in enumerate(df['Quantity']):
    try:
        float(i)
    except:
        print(i)
        print(index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
df_replaced = df.replace(to_replace=[None], value )
# Out:
#   Cell In[27], line 1
#     df_replaced = df.replace(to_replace=[None], value )
#                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
df
# Out:
#      A     B
# 0  1.0  10.0
# 1  2.0  20.0
# 2  3.0   3.0
# 3  4.0   NaN
# 4  5.0  50.0

# %%
df[]

# %%
# Sample sales transaction data
data = {
    'Order_ID': [101, 102, 103, 104, 105],
    'Date': ['2023-07-15', '2023-07-16', '2023-07-17', '2023-07-18', '2023-07-19'],
    'Customer_ID': ['C001', 'C002', 'C003', 'C004', 'C005'],
    'Product': ['Laptop', 'Keyboard', 'Monitor', 'Mouse', 'Headphones'],
    'Quantity': ['1', '2', '3', '4', '5'],
    'Price': ['1000.50', '250.25', '350.75', '75.20', '120.99']
}

df = pd.DataFrame(data)
df
# Out:
#    Order_ID        Date Customer_ID     Product Quantity    Price
# 0       101  2023-07-15        C001      Laptop        1  1000.50
# 1       102  2023-07-16        C002    Keyboard        2   250.25
# 2       103  2023-07-17        C003     Monitor        3   350.75
# 3       104  2023-07-18        C004       Mouse        4    75.20
# 4       105  2023-07-19        C005  Headphones        5   120.99

# %%
data_1 = {
    'Budi:['Budi', 'Joko', 'Sumba'],
    'Price:['Rp.10.000', 'Rp.9.000', 'Rp.7.000']
}
# Out:
#   Cell In[39], line 3
#     'Price:['Rp.10.000', 'Rp.9.000', 'Rp.7.000']
#                                               ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
new_data_1.

# %%
data = {
    'Order_ID': [101, 102, 103, 104, 105],
    'Date_Time': ['2023-07-15 10:30:00', '2023-07-16 15:45:00', '2023-07-17 12:00:00', '2023-07-18 09:00:00', '2023-07-19 16:20:00'],
    'Customer_ID': ['C001', 'C002', 'C003', 'C004', 'C005'],
    'Product': ['Laptop', 'Keyboard', 'Monitor', 'Mouse', 'Headphones'],
    'Quantity': [1, 2, 3, 4, 5],
    'Price': [1000, 250, 350, 75, 120]
}

df = pd.DataFrame(data)
df['Date_Time'] = pd.to_datetime(df['Date_Time'])

df
# Out:
#    Order_ID           Date_Time Customer_ID     Product  Quantity  Price
# 0       101 2023-07-15 10:30:00        C001      Laptop         1   1000
# 1       102 2023-07-16 15:45:00        C002    Keyboard         2    250
# 2       103 2023-07-17 12:00:00        C003     Monitor         3    350
# 3       104 2023-07-18 09:00:00        C004       Mouse         4     75
# 4       105 2023-07-19 16:20:00        C005  Headphones         5    120

# %%
# Extract year, month, and day from 'Date_Time'
df['Year'] = df['Date_Time'].dt.year
df['Month'] = df['Date_Time'].dt.month
df['Day'] = df['Date_Time'].dt.day

df[['Date_Time', 'Year', 'Month', 'Day']]
# Out:
#             Date_Time  Year  Month  Day
# 0 2023-07-15 10:30:00  2023      7   15
# 1 2023-07-16 15:45:00  2023      7   16
# 2 2023-07-17 12:00:00  2023      7   17
# 3 2023-07-18 09:00:00  2023      7   18
# 4 2023-07-19 16:20:00  2023      7   19

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})

further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)

city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0
